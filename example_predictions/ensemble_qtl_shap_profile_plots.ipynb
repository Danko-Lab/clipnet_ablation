# %%
"""
This notebook plots DeepSHAP profile tracks for the QTL examples (Supp. Fig. 3).
"""
# Out:
# '\nThis notebook plots DeepSHAP profile tracks for the QTL examples (Supp. Fig. 3).\n'

# %%
import numpy as np
import os
import matplotlib.pyplot as plt
import sys
sys.path.append("../../clipnet")
from utils import plot_weights

# %%
# PRINT COMMANDS TO DOWNLOAD AND EXTRACT DATA

# Set SCRATCH to where you want to download data to
SCRATCH = "/Users/adamhe/github/scratch"

URL = "https://zenodo.org/records/10597358/files"
TAR = "example_tracks_and_deepshap.tar.gz"
print(f"wget {URL}/{TAR} -P {SCRATCH}")
print(f"tar -xvzf {SCRATCH}/{TAR}")
# Out:
# wget https://zenodo.org/records/10597358/files/example_tracks_and_deepshap.tar.gz -P /Users/adamhe/github/scratch
# tar -xvzf /Users/adamhe/github/scratch/example_tracks_and_deepshap.tar.gz

# %%
# Load data

# SHAP scores
shap = np.load("./subsample_qtl_examples_profile.npz")
#mean_shap = np.array([shap[fold] for fold in shap.files]).mean(axis=0)

# %%
shap
# Out:
# NpzFile './subsample_qtl_examples_profile.npz' with keys: n5_run0, n5_run1, n5_run2, n5_run3, n5_run4...

# %%
plot_weights(shap["n30_run4"][0, :, 250:750], neg_height=-2e-6, pos_height=6e-6, subticks_frequency=50)
#plt.savefig("img/ensemble_deepshap_profile_rs185220G.pdf")

# %%
plot_weights(shap["n30_run0"][0, :, 250:750], neg_height=-5e-6, pos_height=4e-5, subticks_frequency=50)
#plt.savefig("img/ensemble_deepshap_profile_rs185220G.pdf")

# %%
plot_weights(mean_shap[0, :, 497:630], neg_height=-2e-6, pos_height=6e-6, subticks_frequency=50)
plt.savefig("img/ensemble_deepshap_profile_rs185220G_inset.pdf")

# %%
plot_weights(mean_shap[1, :, 250:750], neg_height=-2e-6, pos_height=6e-6, subticks_frequency=50)
plt.savefig("img/ensemble_deepshap_profile_rs185220A.pdf")

# %%
plot_weights(mean_shap[1, :, 497:630], neg_height=-2e-6, pos_height=6e-6, subticks_frequency=50)
plt.savefig("img/ensemble_deepshap_profile_rs185220A_inset.pdf")

# %%
plot_weights(mean_shap[2, :, 250:750], neg_height=-2.4e-5, pos_height=7.2e-5, subticks_frequency=50)
plt.savefig("img/ensemble_deepshap_profile_rs8050061C.pdf")

# %%
plot_weights(mean_shap[2, :, 440:540], neg_height=-2.4e-5, pos_height=7.2e-5, subticks_frequency=50)
plt.savefig("img/ensemble_deepshap_profile_rs8050061C_inset.pdf")

# %%
plot_weights(mean_shap[3, :, 250:750], neg_height=-2.4e-5, pos_height=7.2e-5, subticks_frequency=50)
plt.savefig("img/ensemble_deepshap_profile_rs8050061T.pdf")

# %%
plot_weights(mean_shap[3, :, 440:540], neg_height=-2.4e-5, pos_height=7.2e-5, subticks_frequency=50)
plt.savefig("img/ensemble_deepshap_profile_rs8050061T_inset.pdf")

# %%
plot_weights(mean_shap[4, :, 250:750], neg_height=-1e-5, pos_height=3e-5, subticks_frequency=50)
plt.savefig("img/ensemble_deepshap_profile_rs1016110C.pdf")

# %%
plot_weights(mean_shap[5, :, 250:750], neg_height=-1e-5, pos_height=3e-5, subticks_frequency=50)
plt.savefig("img/ensemble_deepshap_profile_rs1016110T.pdf")
